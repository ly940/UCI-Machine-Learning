# %%
library(tidyverse)
library(repr)
library(tidymodels)
# Out:
# ── Attaching packages ─────────────────────────────────────── tidyverse 1.3.0 ──
#
# ✔ ggplot2 3.3.2     ✔ purrr   0.3.4
# ✔ tibble  3.0.3     ✔ dplyr   1.0.2
# ✔ tidyr   1.1.2     ✔ stringr 1.4.0
# ✔ readr   1.3.1     ✔ forcats 0.5.0
#
# Warning message:
# “package ‘ggplot2’ was built under R version 4.0.1”
# Warning message:
# “package ‘tibble’ was built under R version 4.0.2”
# Warning message:
# “package ‘tidyr’ was built under R version 4.0.2”
# Warning message:
# “package ‘dplyr’ was built under R version 4.0.2”
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()
#
# Warning message:
# “package ‘tidymodels’ was built under R version 4.0.2”
# ── Attaching packages ────────────────────────────────────── tidymodels 0.1.1 ──
#
# ✔ broom     0.7.0      ✔ recipes   0.1.13
# ✔ dials     0.0.9      ✔ rsample   0.0.7
# ✔ infer     0.5.4      ✔ tune      0.1.1
# ✔ modeldata 0.0.2      ✔ workflows 0.2.0
# ✔ parsnip   0.1.3      ✔ yardstick 0.0.7
#
# Warning message:
# “package ‘broom’ was built under R version 4.0.2”
# Warning message:
# “package ‘dials’ was built under R version 4.0.2”
# Warning message:
# “package ‘infer’ was built under R version 4.0.3”
# Warning message:
# “package ‘modeldata’ was built under R version 4.0.1”
# Warning message:
# “package ‘parsnip’ was built under R version 4.0.2”
# Warning message:
# “package ‘recipes’ was built under R version 4.0.1”
# Warning message:
# “package ‘tune’ was built under R version 4.0.2”
# Warning message:
# “package ‘workflows’ was built under R version 4.0.2”
# Warning message:
# “package ‘yardstick’ was built under R version 4.0.2”
# ── Conflicts ───────────────────────────────────────── tidymodels_conflicts() ──
# ✖ scales::discard() masks purrr::discard()
# ✖ dplyr::filter()   masks stats::filter()
# ✖ recipes::fixed()  masks stringr::fixed()
# ✖ dplyr::lag()      masks stats::lag()
# ✖ yardstick::spec() masks readr::spec()
# ✖ recipes::step()   masks stats::step()

# %%
student_performance <- read_delim("student-por.csv", delim = ";")
# Out:
# Parsed with column specification:
# cols(
#   .default = col_character(),
#   age = col_double(),
#   Medu = col_double(),
#   Fedu = col_double(),
#   traveltime = col_double(),
#   studytime = col_double(),
#   failures = col_double(),
#   famrel = col_double(),
#   freetime = col_double(),
#   goout = col_double(),
#   Dalc = col_double(),
#   Walc = col_double(),
#   health = col_double(),
#   absences = col_double(),
#   G1 = col_double(),
#   G2 = col_double(),
#   G3 = col_double()
# )
#
# See spec(...) for full column specifications.

# %%
head(student_performance)
# Out:
#   school sex age address famsize Pstatus Medu Fedu Mjob     Fjob     ⋯ famrel
# 1 GP     F   18  U       GT3     A       4    4    at_home  teacher  ⋯ 4
# 2 GP     F   17  U       GT3     T       1    1    at_home  other    ⋯ 5
# 3 GP     F   15  U       LE3     T       1    1    at_home  other    ⋯ 4
# 4 GP     F   15  U       GT3     T       4    2    health   services ⋯ 3
# 5 GP     F   16  U       GT3     T       3    3    other    other    ⋯ 4
# 6 GP     M   16  U       LE3     T       4    3    services other    ⋯ 5
#   freetime goout Dalc Walc health absences G1 G2 G3
# 1 3        4     1    1    3      4         0 11 11
# 2 3        3     1    1    3      2         9 11 11
# 3 3        2     2    3    3      6        12 13 12
# 4 2        2     1    1    5      0        14 14 14
# 5 3        2     1    2    5      0        11 13 13
# 6 4        2     1    2    5      6        12 12 13

# %%
ncol(student_performance)
# Out:
# [1] 33

# %%
nrow(student_performance)
# Out:
# [1] 649

# %%
missing_data <- sum(is.na(student_performance))
missing_data
# Out:
# [1] 0

# %%
student_performance_training <- student_performance[1:316,]
student_performance_training
student_performance_test <- student_performance[317:395,]
student_performance_test
# Out:
#     school sex age address famsize Pstatus Medu Fedu Mjob     Fjob     ⋯ famrel
# 1   GP     F   18  U       GT3     A       4    4    at_home  teacher  ⋯ 4
# 2   GP     F   17  U       GT3     T       1    1    at_home  other    ⋯ 5
# 3   GP     F   15  U       LE3     T       1    1    at_home  other    ⋯ 4
# 4   GP     F   15  U       GT3     T       4    2    health   services ⋯ 3
# 5   GP     F   16  U       GT3     T       3    3    other    other    ⋯ 4
# 6   GP     M   16  U       LE3     T       4    3    services other    ⋯ 5
# 7   GP     M   16  U       LE3     T       2    2    other    other    ⋯ 4
# 8   GP     F   17  U       GT3     A       4    4    other    teacher  ⋯ 4
# 9   GP     M   15  U       LE3     A       3    2    services other    ⋯ 4
# 10  GP     M   15  U       GT3     T       3    4    other    other    ⋯ 5
# 11  GP     F   15  U       GT3     T       4    4    teacher  health   ⋯ 3
# 12  GP     F   15  U       GT3     T       2    1    services other    ⋯ 5
# 13  GP     M   15  U       LE3     T       4    4    health   services ⋯ 4
# 14  GP     M   15  U       GT3     T       4    3    teacher  other    ⋯ 5
# 15  GP     M   15  U       GT3     A       2    2    other    other    ⋯ 4
# 16  GP     F   16  U       GT3     T       4    4    health   other    ⋯ 4
# 17  GP     F   16  U       GT3     T       4    4    services services ⋯ 3
# 18  GP     F   16  U       GT3     T       3    3    other    other    ⋯ 5
# 19  GP     M   17  U       GT3     T       3    2    services services ⋯ 5
# 20  GP     M   16  U       LE3     T       4    3    health   other    ⋯ 3
# 21  GP     M   15  U       GT3     T       4    3    teacher  other    ⋯ 4
# 22  GP     M   15  U       GT3     T       4    4    health   health   ⋯ 5
# 23  GP     M   16  U       LE3     T       4    2    teacher  other    ⋯ 4
# 24  GP     M   16  U       LE3     T       2    2    other    other    ⋯ 5
# 25  GP     F   15  R       GT3     T       2    4    services health   ⋯ 4
# 26  GP     F   16  U       GT3     T       2    2    services services ⋯ 1
# 27  GP     M   15  U       GT3     T       2    2    other    other    ⋯ 4
# 28  GP     M   15  U       GT3     T       4    2    health   services ⋯ 2
# 29  GP     M   16  U       LE3     A       3    4    services other    ⋯ 5
# 30  GP     M   16  U       GT3     T       4    4    teacher  teacher  ⋯ 4
# ⋮   ⋮      ⋮   ⋮   ⋮       ⋮       ⋮       ⋮    ⋮    ⋮        ⋮        ⋱ ⋮
# 287 GP     M   17  R       GT3     T       2    1    other    other    ⋯ 4
# 288 GP     M   17  U       LE3     T       1    1    health   other    ⋯ 4
# 289 GP     F   18  U       LE3     A       2    1    other    other    ⋯ 4
# 290 GP     F   17  U       LE3     T       4    2    teacher  services ⋯ 4
# 291 GP     F   19  U       GT3     T       2    2    services services ⋯ 4
# 292 GP     M   18  U       LE3     T       2    1    services other    ⋯ 4
# 293 GP     F   17  R       GT3     T       4    2    other    other    ⋯ 4
# 294 GP     F   18  U       LE3     T       1    1    other    at_home  ⋯ 4
# 295 GP     F   18  R       GT3     T       2    2    other    other    ⋯ 3
# 296 GP     M   19  U       LE3     A       4    3    services at_home  ⋯ 4
# 297 GP     M   18  U       GT3     T       2    1    other    other    ⋯ 5
# 298 GP     M   17  R       GT3     T       2    2    other    services ⋯ 5
# 299 GP     F   17  U       LE3     T       2    2    services services ⋯ 3
# 300 GP     F   20  R       GT3     T       2    1    other    other    ⋯ 1
# 301 GP     F   18  U       GT3     T       4    3    services other    ⋯ 3
# 302 GP     M   18  U       GT3     T       4    3    teacher  other    ⋯ 4
# 303 GP     M   18  R       GT3     T       3    2    other    other    ⋯ 5
# 304 GP     F   17  U       GT3     T       3    3    other    other    ⋯ 3
# 305 GP     F   18  U       GT3     T       2    2    at_home  services ⋯ 4
# 306 GP     M   17  U       GT3     T       2    2    other    other    ⋯ 4
# 307 GP     M   18  R       LE3     A       3    4    other    other    ⋯ 4
# 308 GP     M   17  U       GT3     T       3    1    services other    ⋯ 5
# 309 GP     F   18  R       GT3     T       4    4    teacher  other    ⋯ 4
# 310 GP     M   18  U       GT3     T       4    2    health   other    ⋯ 5
# 311 GP     F   18  R       GT3     T       2    1    other    other    ⋯ 4
# 312 GP     F   19  U       GT3     T       3    3    other    services ⋯ 4
# 313 GP     F   18  U       GT3     T       2    3    other    services ⋯ 4
# 314 GP     F   18  U       LE3     T       1    1    other    other    ⋯ 4
# 315 GP     M   17  R       GT3     T       1    2    at_home  at_home  ⋯ 3
# 316 GP     F   18  U       GT3     T       2    1    other    other    ⋯ 4
#     freetime goout Dalc Walc health absences G1 G2 G3
# 1   3        4     1    1    3       4        0 11 11
# 2   3        3     1    1    3       2        9 11 11
# 3   3        2     2    3    3       6       12 13 12
# 4   2        2     1    1    5       0       14 14 14
# 5   3        2     1    2    5       0       11 13 13
# 6   4        2     1    2    5       6       12 12 13
# 7   4        4     1    1    3       0       13 12 13
# 8   1        4     1    1    1       2       10 13 13
# 9   2        2     1    1    1       0       15 16 17
# 10  5        1     1    1    5       0       12 12 13
# 11  3        3     1    2    2       2       14 14 14
# 12  2        2     1    1    4       0       10 12 13
# 13  3        3     1    3    5       0       12 13 12
# 14  4        3     1    2    3       0       12 12 13
# 15  5        2     1    1    3       0       14 14 15
# 16  4        4     1    2    2       6       17 17 17
# 17  2        3     1    2    2      10       13 13 14
# 18  3        2     1    1    4       2       13 14 14
# 19  5        5     2    4    5       2        8  8  7
# 20  1        3     1    3    5       6       12 12 12
# 21  4        1     1    1    1       0       12 13 14
# 22  4        2     1    1    5       0       11 12 12
# 23  5        1     1    3    5       0       12 13 14
# 24  4        4     2    4    5       2       10 10 10
# 25  3        2     1    1    5       2       10 11 10
# 26  2        2     1    3    5       6       10 11 12
# 27  2        2     1    2    5       8       11 12 12
# 28  2        4     2    4    1       0       11 11 11
# 29  3        3     1    1    5       2       12 12 13
# 30  4        5     5    5    5       4       12 11 12
# ⋮   ⋮        ⋮     ⋮    ⋮    ⋮      ⋮        ⋮  ⋮  ⋮
# 287 4        2     2    4    5       0       12 12 13
# 288 4        4     1    2    5       0        9 10 10
# 289 3        4     1    3    5       2       12 12 13
# 290 2        3     1    1    4       2       14 15 17
# 291 3        3     1    1    5       0       10 10 11
# 292 4        5     4    4    5       4       11 10 11
# 293 3        4     1    3    5       2       11 12 14
# 294 4        3     2    3    3       4       11 12 14
# 295 2        3     1    1    5       4       11 11 13
# 296 3        1     1    1    1       4       11 13 14
# 297 2        4     1    2    4       2       16 16 16
# 298 2        2     1    1    4       0        9 10 10
# 299 4        1     1    1    2       2       10 11 12
# 300 2        3     1    2    2       8       10 12 12
# 301 1        2     1    3    2       2       15 15 15
# 302 3        2     1    1    3       2       10 10 11
# 303 3        2     1    1    3       2       10 11 12
# 304 2        3     1    1    4       2       15 12 13
# 305 3        3     1    1    3       0       11 12 13
# 306 4        4     2    3    4       8        8  8  9
# 307 2        5     3    4    1       6       15 16 16
# 308 4        4     3    4    5       0       11 11 14
# 309 3        4     2    2    4       8       10 11 12
# 310 4        5     1    3    5       4       10 12 14
# 311 3        5     1    2    3      12        8  9 10
# 312 3        5     3    3    5      16       11 12 12
# 313 5        5     1    3    2      10       16 16 16
# 314 4        3     1    1    3       2       13 13 13
# 315 5        2     2    2    1       2       16 17 18
# 316 2        5     1    2    1       8       14 14 15
#    school sex age address famsize Pstatus Medu Fedu Mjob     Fjob     ⋯ famrel
# 1  GP     F   17  U       GT3     T       2    4    at_home  health   ⋯ 4
# 2  GP     F   17  U       LE3     T       2    2    services other    ⋯ 4
# 3  GP     F   18  R       GT3     A       3    2    other    services ⋯ 4
# 4  GP     M   18  U       GT3     T       4    4    teacher  services ⋯ 3
# 5  GP     F   18  U       GT3     T       4    4    health   health   ⋯ 2
# 6  GP     F   17  U       GT3     T       2    2    other    services ⋯ 4
# 7  GP     F   19  R       GT3     T       3    2    services services ⋯ 3
# 8  GP     M   18  U       LE3     T       4    3    teacher  services ⋯ 4
# 9  GP     M   18  U       GT3     T       1    2    at_home  other    ⋯ 3
# 10 GP     M   17  U       LE3     A       4    1    services other    ⋯ 4
# 11 GP     M   17  U       LE3     A       3    2    teacher  services ⋯ 4
# 12 GP     F   18  R       LE3     T       1    1    at_home  other    ⋯ 5
# 13 GP     F   18  U       GT3     T       1    1    other    other    ⋯ 5
# 14 GP     F   17  U       GT3     T       2    2    other    other    ⋯ 5
# 15 GP     F   18  U       GT3     T       2    1    other    other    ⋯ 4
# 16 GP     M   17  U       GT3     T       1    1    other    other    ⋯ 4
# 17 GP     F   18  U       GT3     T       2    2    at_home  at_home  ⋯ 4
# 18 GP     F   17  U       GT3     T       1    1    services teacher  ⋯ 4
# 19 GP     M   18  U       GT3     T       2    1    services services ⋯ 4
# 20 GP     M   18  U       LE3     A       4    4    teacher  teacher  ⋯ 5
# 21 GP     M   18  U       GT3     T       4    2    teacher  other    ⋯ 4
# 22 GP     F   17  U       GT3     T       4    3    health   services ⋯ 4
# 23 GP     F   17  R       LE3     T       3    1    services other    ⋯ 3
# 24 GP     M   18  R       LE3     T       3    2    services other    ⋯ 5
# 25 GP     M   17  U       GT3     T       3    3    health   other    ⋯ 4
# 26 GP     F   19  U       GT3     T       4    4    health   other    ⋯ 2
# 27 GP     F   18  U       LE3     T       4    3    other    other    ⋯ 4
# 28 GP     F   18  U       GT3     T       4    3    other    other    ⋯ 4
# 29 GP     M   18  U       LE3     T       4    4    teacher  teacher  ⋯ 1
# 30 GP     F   18  U       LE3     A       4    4    health   other    ⋯ 4
# ⋮  ⋮      ⋮   ⋮   ⋮       ⋮       ⋮       ⋮    ⋮    ⋮        ⋮        ⋱ ⋮
# 50 GP     F   17  U       GT3     A       4    3    services services ⋯ 5
# 51 GP     F   17  U       LE3     A       3    3    services other    ⋯ 5
# 52 GP     F   17  U       LE3     T       2    1    other    other    ⋯ 4
# 53 GP     M   18  U       LE3     T       4    4    other    other    ⋯ 4
# 54 GP     F   19  U       GT3     T       1    1    other    other    ⋯ 1
# 55 GP     F   19  U       LE3     A       1    1    other    other    ⋯ 5
# 56 GP     F   18  U       GT3     T       2    2    other    other    ⋯ 4
# 57 GP     F   17  U       GT3     T       2    2    other    other    ⋯ 4
# 58 GP     F   17  R       LE3     T       2    2    services services ⋯ 3
# 59 GP     F   17  U       GT3     T       3    1    services services ⋯ 3
# 60 GP     F   17  U       LE3     T       0    2    at_home  at_home  ⋯ 3
# 61 GP     F   18  U       GT3     T       1    1    other    other    ⋯ 4
# 62 GP     M   18  U       GT3     T       4    4    other    other    ⋯ 4
# 63 GP     M   17  U       GT3     T       3    3    other    services ⋯ 4
# 64 GP     M   17  R       GT3     T       2    2    services other    ⋯ 4
# 65 GP     F   17  U       GT3     T       4    4    teacher  services ⋯ 5
# 66 GP     F   17  U       GT3     T       4    4    teacher  teacher  ⋯ 4
# 67 GP     F   17  U       GT3     T       3    3    at_home  other    ⋯ 4
# 68 GP     M   18  U       LE3     T       2    2    other    other    ⋯ 4
# 69 GP     M   19  R       GT3     T       3    2    at_home  services ⋯ 5
# 70 GP     F   18  U       GT3     T       2    2    at_home  other    ⋯ 4
# 71 GP     F   17  R       GT3     T       2    4    at_home  other    ⋯ 4
# 72 GP     M   18  U       GT3     T       2    2    other    other    ⋯ 5
# 73 GP     F   18  U       GT3     T       3    3    services services ⋯ 5
# 74 GP     F   18  U       LE3     T       2    2    other    other    ⋯ 4
# 75 GP     F   18  R       GT3     T       2    2    at_home  other    ⋯ 4
# 76 GP     F   17  U       GT3     T       3    4    services other    ⋯ 4
# 77 GP     F   17  U       GT3     T       3    2    other    other    ⋯ 4
# 78 GP     F   18  U       LE3     T       3    3    services services ⋯ 5
# 79 GP     F   17  R       GT3     A       3    2    other    other    ⋯ 4
#    freetime goout Dalc Walc health absences G1 G2 G3
# 1  3        3     1    1    1       6       15 16 16
# 2  4        4     2    3    5       6       12 12 12
# 3  1        1     1    1    5      15       12  9 10
# 4  2        4     1    4    3       6       11 12 12
# 5  4        4     1    1    4       2       14 12 13
# 6  2        3     1    1    1       8       13 15 15
# 7  3        3     4    3    3       0        9  8 10
# 8  2        3     1    2    1       0       10 10 10
# 9  4        4     2    4    4      10       10 10 11
# 10 5        4     2    4    5      22       11 11 10
# 11 4        4     3    4    3      18       13 13 13
# 12 2        2     1    1    3       2       17 17 18
# 13 4        4     1    1    4       0       12 13 13
# 14 4        5     1    2    5      12       12 12 14
# 15 3        1     1    1    5      10       12 13 14
# 16 3        3     1    2    4       0       12 12 12
# 17 3        3     1    2    2       0       18 18 18
# 18 3        3     1    1    3       0       13 13 14
# 19 2        4     1    3    2       0       14 15 15
# 20 4        3     1    1    2       0       17 17 17
# 21 3        2     1    4    5       2       15 16 16
# 22 2        2     1    2    3       0       17 18 18
# 23 1        2     1    1    3       0       18 19 19
# 24 4        2     1    1    4       0       14 15 15
# 25 4        3     1    3    5       0       14 15 15
# 26 3        4     2    3    2       2       14 13 13
# 27 4        5     1    2    2       0       13 14 14
# 28 3        3     1    1    3       0       16 17 17
# 29 4        2     2    2    1       0       18 18 17
# 30 2        4     1    1    4       0       14 15 15
# ⋮  ⋮        ⋮     ⋮    ⋮    ⋮      ⋮        ⋮  ⋮  ⋮
# 50 2        2     1    2    5      14       15 14 17
# 51 3        3     1    1    5       0       12 12 13
# 52 2        3     2    2    2       2       11 12 14
# 53 2        5     3    4    5       2        8  9 11
# 54 5        5     4    3    5      12       10 10 11
# 55 3        4     1    1    4       2        8  8  9
# 56 3        5     2    4    5       2       10 10 10
# 57 2        2     1    1    3       4       14 13 13
# 58 3        2     2    2    3       0       11 11 10
# 59 4        3     2    3    5       0       17 18 17
# 60 3        3     2    3    2       0       14 14 15
# 61 5        5     1    2    2       0       14 14 14
# 62 3        3     2    2    3       0       13 14 13
# 63 3        5     3    5    5       0       17 18 17
# 64 4        5     5    5    4       2       11 10 10
# 65 4        4     1    3    4       0       13 12 13
# 66 3        3     1    2    4       4       15 14 15
# 67 2        5     2    5    5       2       11 12 11
# 68 5        5     2    4    5       0       11 11 12
# 69 3        4     2    2    5       0       11 10 10
# 70 2        5     1    1    2       2       10  9 10
# 71 4        3     1    1    5       0       15 15 15
# 72 4        2     1    2    5       6       15 14 15
# 73 3        4     1    1    4       8       10 11 12
# 74 3        3     1    1    2       0       10  9 12
# 75 4        4     1    1    4       6       14 13 14
# 76 4        5     1    3    5       8       11 13 14
# 77 3        2     2    3    2       0       12 13 15
# 78 3        3     1    1    1       4       14 14 15
# 79 3        3     2    3    2       0       14 14 16

# %%
student_performance_training <- select(student_performance_training, c("studytime", "traveltime", "G3")) 
student_performance_training

study_vs_travel <- ggplot(student_performance_training, aes(x = studytime , y = traveltime)) + 
     geom_points() +
     labs(x= “Study time” , y = “Travel time”)
     theme(text = element_text(size = 20))
study_vs_travel
# Out:
# Error in parse(text = x, srcfile = src): <text>:5:14: unexpected input
# 4:      geom_points() +
# 5:      labs(x= “
#                 ^
# Traceback:
